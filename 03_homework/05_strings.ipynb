# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here
'''
my name is sunny

this is to test a multi-line string

let's see if it works well

'''
# Out:
# "\nmy name is sunny\n\nthis is to test a multi-line string\n\nlet's see if it works well\n\n"

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here

'hello' + ' ' + 'world'
# Out:
# 'hello world'
